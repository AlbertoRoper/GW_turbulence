# %%
import initialize_memory as i
print(i.__doc__)
i.run()
# Out:
# initialize_memory.py is a Python routine that reads the data
# and stores the resulting run variables as pickle files.
#
# The function run() executes the code.
#
# Reading run A4_nl
#
# Spectra computed:
# ['Tpq', 'GWh', 'ele', 'VCT', 'mag', 'GWs', 'SCL', 'Str', 'TGW', 'helele', 'helGWh', 'helGWs', 'helmag', 'helStr']
#
#
# Reading run A4_l
#
# Spectra computed:
# ['Tpq', 'GWh', 'ele', 'VCT', 'mag', 'GWs', 'SCL', 'Str', 'helele', 'helGWh', 'helGWs', 'helmag', 'helStr']
#
#
# Reading run A3_nl
#
# Spectra computed:
# ['Tpq', 'GWh', 'ele', 'VCT', 'mag', 'GWs', 'SCL', 'Str', 'TGW', 'helele', 'helGWh', 'helGWs', 'helmag', 'helStr']
#
#
# Reading run A3_l
#
# Spectra computed:
# ['Tpq', 'GWh', 'ele', 'VCT', 'mag', 'GWs', 'SCL', 'Str', 'helele', 'helGWh', 'helGWs', 'helmag', 'helStr']
#
#
# Reading run A2_nl
#
# Spectra computed:
# ['Tpq', 'GWh', 'ele', 'VCT', 'mag', 'GWs', 'SCL', 'Str', 'TGW', 'helele', 'helGWh', 'helGWs', 'helmag', 'helStr']
#
#
# Reading run A2_l
#
# Spectra computed:
# ...
